# %% [markdown]
# #Task2: Try Linear regression on same prediction data using Tensorflow

# %%
import numpy as np
import tensorflow as tf

# %%
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70],[73, 67, 43], [91, 88, 64], 
                   [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], 
                   [69, 96, 70]], dtype='float64')

targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], 
                    [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float64')

# %%
inputs = tf.Variable(inputs)
targets = tf.Variable(targets)
print("targets :\n",targets)
# Out:
# targets :
#  <tf.Variable 'Variable:0' shape=(15, 2) dtype=float64, numpy=
# array([[ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.]])>

# %%
v = np.random.rand(3,2)
r = np.random.randn(2)
v = tf.Variable(v)
r = tf.Variable(r)

print(v)
print("\n",r)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[0.29437053, 0.00217875],
#        [0.7269421 , 0.60247434],
#        [0.58632185, 0.83586757]])>
#
#  <tf.Variable 'Variable:0' shape=(2,) dtype=float64, numpy=array([1.21637132, 0.33731545])>

# %%
def model(s):
    return s @ v + r

# %%
prediction = model(inputs)
print(prediction)
# Out:
# tf.Tensor(
# [[ 96.62238033  76.8044497 ]
#  [129.49959282 107.04884706]
#  [158.24351637 129.73874613]
#  [ 84.19458411  57.39304386]
#  [132.35690909 116.83591475]
#  [ 96.62238033  76.8044497 ]
#  [129.49959282 107.04884706]
#  [158.24351637 129.73874613]
#  [ 84.19458411  57.39304386]
#  [132.35690909 116.83591475]
#  [ 96.62238033  76.8044497 ]
#  [129.49959282 107.04884706]
#  [158.24351637 129.73874613]
#  [ 84.19458411  57.39304386]
#  [132.35690909 116.83591475]], shape=(15, 2), dtype=float64)

# %%
def mse(t1,t2):
    return tf.reduce_mean(tf.square(t1 - t2))
print(mse(prediction,targets))
# Out:
# tf.Tensor(1078.6520634726608, shape=(), dtype=float64)

# %%
epochs = 40
for epoch_count in range(epochs):
    
    with tf.GradientTape(persistent=True) as t:
        current_loss = mse(targets, model(inputs))

    v1 = t.gradient(current_loss,v)
    r1 = t.gradient(current_loss,r)

    v.assign_sub(1e-4 * v1)
    r.assign_sub(1e-4 * r1)
        
    print(f" \n Epoch count: {epoch_count} \n Loss value: {current_loss.numpy()}")
# Out:
#
#  Epoch count: 0
#  Loss value: 1078.6520634726608
#
#  Epoch count: 1
#  Loss value: 716.4643066642382
#
#  Epoch count: 2
#  Loss value: 484.86774231951046
#
#  Epoch count: 3
#  Loss value: 335.5821205561712
#
#  Epoch count: 4
#  Loss value: 238.3282668417174
#
#  Epoch count: 5
#  Loss value: 174.0976363863606
#
#  Epoch count: 6
#  Loss value: 130.9406423150974
#
#  Epoch count: 7
#  Loss value: 101.33085746171534
#
#  Epoch count: 8
#  Loss value: 80.51519820186738
#
#  Epoch count: 9
#  Loss value: 65.48104157710225
#
#  Epoch count: 10
#  Loss value: 54.309387184709344
#
#  Epoch count: 11
#  Loss value: 45.76960939674545
#
#  Epoch count: 12
#  Loss value: 39.06541970102223
#
#  Epoch count: 13
#  Loss value: 33.67548881537291
#
#  Epoch count: 14
#  Loss value: 29.253343136156698
#
#  Epoch count: 15
#  Loss value: 25.564391717244593
#
#  Epoch count: 16
#  Loss value: 22.446224725540855
#
#  Epoch count: 17
#  Loss value: 19.783507958727846
#
#  Epoch count: 18
#  Loss value: 17.492041518525305
#
#  Epoch count: 19
#  Loss value: 15.508580422624615
#
#  Epoch count: 20
#  Loss value: 13.784285199584025
#
#  Epoch count: 21
#  Loss value: 12.28046561576823
#
#  Epoch count: 22
#  Loss value: 10.965778479023248
#
#  Epoch count: 23
#  Loss value: 9.814352217183556
#
#  Epoch count: 24
#  Loss value: 8.804506254635422
#
#  Epoch count: 25
#  Loss value: 7.917855662225406
#
#  Epoch count: 26
#  Loss value: 7.138668387194897
#
#  Epoch count: 27
#  Loss value: 6.453390633397206
#
#  Epoch count: 28
#  Loss value: 5.850286329408928
#
#  Epoch count: 29
#  Loss value: 5.319155772374387
#
#  Epoch count: 30
#  Loss value: 4.85111064954825
#
#  Epoch count: 31
#  Loss value: 4.438390335455372
#
#  Epoch count: 32
#  Loss value: 4.0742092801491925
#
#  Epoch count: 33
#  Loss value: 3.75262847082684
#
#  Epoch count: 34
#  Loss value: 3.4684460094654215
#
#  Epoch count: 35
#  Loss value: 3.2171032076854065
#
#  Epoch count: 36
#  Loss value: 2.9946035109708027
#
#  Epoch count: 37
#  Loss value: 2.7974421877868725
#
#  Epoch count: 38
#  Loss value: 2.622545156112891
#
#  Epoch count: 39
#  Loss value: 2.4672156344888614
